# %%
import sys, os
sys.path.insert(0, os.path.abspath("../.."))
# %load_ext ElasticNotebook

# %%
# %%RecordEvent
# x = 1

# %%
# %%RecordEvent
# y = x
# x = x + 1
# z = 1
# a = 1
# del a
# a = 2

# %%
# %%RecordEvent
# # Record imported libraries
# import numpy as np
# from numpy import random

# %%
# %%RecordEvent
# b = 1

# %%
# %%RecordEvent
# def func():
#     global b
#     b += 1
# func()

# %%
# %Inspect

# %%
# %Checkpoint checkpoints/simple.pickle
# Out:
# ---------------------------
# variables to migrate:
# ---------------------------
# variables to recompute:
# random 72
# z 28
# b 28
# a 28
# func 136
# np 72
# y 28
# x 28
# ---------------------------
# OEs to recompute:
# 1 0.0003590583801269531
# 2 0.0001652240753173828
# 0 0.0001163482666015625
# 3 0.00010800361633300781
# 4 0.00023603439331054688
# Checkpoint saved to: checkpoints/simple.pickle
