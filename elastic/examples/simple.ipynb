# %%
import sys, os
sys.path.insert(0, os.path.abspath("../.."))
# %load_ext ElasticNotebook

# %%
# %%RecordEvent
# x = 1

# %%
# %%RecordEvent
# y = x
# x = x + 1
# z = 1
# a = 1
# del a
# a = 2

# %%
# %%RecordEvent
# # Record imported libraries
# import numpy as np
# from numpy import random

# %%
# %%RecordEvent
# b = 1

# %%
# %%RecordEvent
# def func():
#     global b
#     b += 1
# func()

# %%
# %Inspect

# %%
# %SetOptimizer greedy
# %SetOptimizer random
# %SetOptimizer migrate_all
# %SetOptimizer recompute_all
# Out:
# HERE1
# <class 'str'> <class 'str'>
# HERE

# %%
# %Checkpoint checkpoints/simple.pickle
# Out:
# ---------------------------
# variables to migrate:
# b 28
# y 28
# z 28
# x 28
# a 28
# ---------------------------
# variables to recompute:
# random 72
# func 144
# np 72
# ---------------------------
# OEs to recompute:
# 2 0.0009961128234863281
# 4 0.0010082721710205078
# Checkpoint saved to: checkpoints/simple.pickle
